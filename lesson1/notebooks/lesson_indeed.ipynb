# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
my_series = pd.Series([5,6,7,8,9,10], index=['a','b','c','d','e','f']) # np.rabd(5)
my_series
# Out:
# a     5
# b     6
# c     7
# d     8
# e     9
# f    10
# dtype: int64

# %%
my_series = pd.Series({'a': 5, 'b': 6, 'c': 7, 'd': 8})
my_series
# Out:
# a    5
# b    6
# c    7
# d    8
# dtype: int64

# %%
my_series.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
my_series.index = ['A', 'B', 'C', 'D']
my_series
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-f03de60a65e1> in <module>()
# ----> 1 my_series.index = ['A', 'B', 'C', 'D']
#       2 my_series
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    3092         try:
#    3093             object.__getattribute__(self, name)
# -> 3094             return object.__setattr__(self, name, value)
#    3095         except AttributeError:
#    3096             pass
#
# pandas/_libs/src/properties.pyx in pandas._libs.lib.AxisProperty.__set__ (pandas/_libs/lib.c:45255)()
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _set_axis(self, axis, labels, fastpath)
#     306         object.__setattr__(self, '_index', labels)
#     307         if not fastpath:
# --> 308             self._data.set_axis(axis, labels)
#     309
# ...

# %%
my_series['A', 'C'] = 100
my_series
# Out:
# A    100
# B      6
# C    100
# D      8
# dtype: int64

# %%
new_seria = my_series[my_series > 50]
new_seria
# Out:
# A    100
# C    100
# dtype: int64

# %%
my_series.drop(axis=0, labels='A')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-a1546ce24155> in <module>()
# ----> 1 my_series.drop(axis=0, labels='A')
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# /usr/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
df0 = pd.DataFrame([17.04, 143.5, 9.5, 45.5])
df0
# Out:
#         0
# 0   17.04
# 1  143.50
# 2    9.50
# 3   45.50

# %%
df = pd.DataFrame({
    'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
    'square': [2724902, 17125191, 207600, 603628]
})
df
# Out:
#       country  population    square
# 0  Kazakhstan       17.04   2724902
# 1      Russia      143.50  17125191
# 2     Belarus        9.50    207600
# 3     Ukraine       45.50    603628

# %%
df1 = pd.DataFrame(np.random.randn(4,3), 
                   index=['a', 'b', 'c', 'd'], 
                   columns=['c1', 'c2', 'c3'])
df1
# Out:
#          c1        c2        c3
# a -1.454954 -0.342230 -0.640754
# b  0.741876 -1.284583  0.543137
# c -1.020754  0.172329 -0.323527
# d -2.055501  1.202539  1.034274

# %%
df['country']
# Out:
# 0    Kazakhstan
# 1        Russia
# 2       Belarus
# 3       Ukraine
# Name: country, dtype: object

# %%
type(df1['c1'])
# Out:
# pandas.core.series.Series

# %%
df1.columns
# Out:
# Index(['c1', 'c2', 'c3'], dtype='object')

# %%
df = pd.DataFrame({
    'country': ['Kazakhstan', 'Russia', 'Belarus', 'Ukraine'],
    'population': [17.04, 143.5, 9.5, 45.5],
    'square': [2724902, 17125191, 207600, 603628]
}, index=['KZ', 'RU', 'BY', 'UA'])
df
# Out:
#        country  population    square
# KZ  Kazakhstan       17.04   2724902
# RU      Russia      143.50  17125191
# BY     Belarus        9.50    207600
# UA     Ukraine       45.50    603628

# %%
df.loc[['KZ']]
# Out:
#        country  population   square
# KZ  Kazakhstan       17.04  2724902

# %%
df.at['KZ', 'population']
# Out:
# 17.039999999999999

# %%
df[df.population>20]
# Out:
#     country  population    square
# RU   Russia       143.5  17125191
# UA  Ukraine        45.5    603628

# %%
df.loc['RU'] = ['ROSSSSIA', 1234,4321]
df
# Out:
#        country  population   square
# KZ  Kazakhstan       17.04  2724902
# RU    ROSSSSIA     1234.00     4321
# BY     Belarus        9.50   207600
# UA     Ukraine       45.50   603628

# %%
df['calc'] = df.population / df.square * 1000
df
# Out:
#        country  population   square        calc
# KZ  Kazakhstan       17.04  2724902    0.006253
# RU    ROSSSSIA     1234.00     4321  285.582041
# BY     Belarus        9.50   207600    0.045761
# UA     Ukraine       45.50   603628    0.075378

# %%
newdf = df1.append(df)

# %%
newdf.at[2, 'c0'] = np.nan
newdf.at['c1', 3] = np.nan

# %%
newdf
# Out:
#           c1        c2        c3        calc     country  population  \
# a  -1.454954 -0.342230 -0.640754         NaN         NaN         NaN
# b   0.741876 -1.284583  0.543137         NaN         NaN         NaN
# c  -1.020754  0.172329 -0.323527         NaN         NaN         NaN
# d  -2.055501  1.202539  1.034274         NaN         NaN         NaN
# KZ       NaN       NaN       NaN    0.006253  Kazakhstan       17.04
# RU       NaN       NaN       NaN  285.582041    ROSSSSIA     1234.00
# BY       NaN       NaN       NaN    0.045761     Belarus        9.50
# UA       NaN       NaN       NaN    0.075378     Ukraine       45.50
# 2        NaN       NaN       NaN         NaN         NaN         NaN
# c1       NaN       NaN       NaN         NaN         NaN         NaN
#
#        square  c0   3
# a         NaN NaN NaN
# b         NaN NaN NaN
# c         NaN NaN NaN
# d         NaN NaN NaN
# KZ  2724902.0 NaN NaN
# RU     4321.0 NaN NaN
# BY   207600.0 NaN NaN
# ...

# %%
newdf.dropna(axis=0)
# Out:
# Empty DataFrame
# Columns: [c1, c2, c3, calc, country, population, square, c0, 3]
# Index: []

# %%
df5=pd.read_csv('../../data/video_games_sales.csv')
df5
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 1                                      Super Mario Bros.      NES
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 4                               Pokemon Red/Pokemon Blue       GB
# 5                                                 Tetris       GB
# 6                                  New Super Mario Bros.       DS
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 9                                              Duck Hunt      NES
# 10                                            Nintendogs       DS
# 11                                         Mario Kart DS       DS
# 12                           Pokemon Gold/Pokemon Silver       GB
# ...

# %%
# %%time
df.to_csv('../../data/new_file.csv',index=False)
# Out:
# CPU times: user 1.6 ms, sys: 1.2 ms, total: 2.8 ms
# Wall time: 2.47 ms

# %%
# !less ../../data/new_file.csv
# Out:
# country,population,square,calc
# Kazakhstan,17.04,2724902,0.006253435903382947
# ROSSSSIA,1234.0,4321,285.582041194168
# Belarus,9.5,207600,0.04576107899807322
# Ukraine,45.5,603628,0.07537755041184305
# (END)_file.csv (END)

# %%
??pd.concat

# %%
df5.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df5.shape
# Out:
# (16719, 16)

# %%
df5.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
df5.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
# ...

# %%
df5.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16450.000000  16719.000000  16719.000000  16719.000000
# mean       2006.487356      0.263330      0.145025      0.077602
# std           5.878995      0.813514      0.503283      0.308818
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count    User_Count
# count  16719.000000  16719.000000   8137.000000   8137.000000   7590.000000
# mean       0.047332      0.533543     68.967679     26.360821    162.229908
# std        0.186710      1.547935     13.938165     18.980495    561.282326
# min        0.000000      0.010000     13.000000      3.000000      4.000000
# ...

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16665 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Critic_Score       8137 non-null float64
# Critic_Count       8137 non-null float64
# User_Score         10015 non-null object
# User_Count         7590 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(9), object(7)
# memory usage: 2.0+ MB

# %%
df5.describe(include=['O'])
# Out:
#                                Name Platform   Genre        Publisher  \
# count                         16717    16719   16717            16665
# unique                        11562       31      12              581
# top     Need for Speed: Most Wanted      PS2  Action  Electronic Arts
# freq                             12     2161    3370             1356
#
#        User_Score Developer Rating
# count       10015     10096   9950
# unique         96      1696      8
# top           tbd   Ubisoft      E
# freq         2425       204   3991

# %%
df5['User_Count'].apply(np.mean)
# Out:
# 0         322.0
# 1           NaN
# 2         709.0
# 3         192.0
# 4           NaN
# 5           NaN
# 6         431.0
# 7         129.0
# 8         594.0
# 9           NaN
# 10          NaN
# 11        464.0
# 12          NaN
# 13        146.0
# 14        106.0
# 15         52.0
# 16       3994.0
# 17       1588.0
# 18          NaN
# 19         50.0
# 20          NaN
# 21          NaN
# 22          NaN
# 23       3711.0
# 24        730.0
# 25          NaN
# 26         19.0
# 27          NaN
# 28        314.0
# 29       8713.0
#           ...
# 16689       NaN
# 16690       NaN
# 16691       NaN
# 16692       NaN
# 16693       NaN
# 16694       NaN
# 16695       NaN
# 16696     412.0
# 16697       NaN
# 16698       NaN
# 16699       NaN
# 16700      43.0
# 16701       NaN
# 16702       NaN
# 16703       NaN
# 16704       NaN
# 16705       NaN
# 16706      13.0
# 16707       NaN
# 16708       NaN
# 16709       8.0
# 16710       NaN
# 16711       NaN
# 16712       NaN
# ...

# %%
df10 = df5[df5['Platform'].isin(['PS3', 'PS4', 'Wii'])]

# %%
df10.shape
# Out:
# (3044, 16)

# %%
df10
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 13                                               Wii Fit      Wii
# 15                                          Wii Fit Plus      Wii
# 16                                    Grand Theft Auto V      PS3
# 31                             Call of Duty: Black Ops 3      PS4
# 34                            Call of Duty: Black Ops II      PS3
# 37                        Call of Duty: Modern Warfare 3      PS3
# 39                               Super Smash Bros. Brawl      Wii
# 41                               Call of Duty: Black Ops      PS3
# ...

# %%
g=df10[['Platform','Year_of_Release','Global_Sales']].groupby(['Platform','Year_of_Release'])\
.agg(['min','max','sum'])

# %%
g
# Out:
#                          Global_Sales
#                                   min    max     sum
# Platform Year_of_Release
# PS3      2006.0                  0.01   4.34   20.95
#          2007.0                  0.02   6.68   73.14
#          2008.0                  0.01  10.50  118.48
#          2009.0                  0.01  10.60  130.89
#          2010.0                  0.02  12.63  142.38
#          2011.0                  0.01  13.32  156.79
#          2012.0                  0.01  13.79  107.27
#          2013.0                  0.01  21.04  113.17
#          2014.0                  0.01   5.26   47.63
#          2015.0                  0.01   2.71   16.87
#          2016.0                  0.01   0.73    3.58
# PS4      2013.0                  0.16   3.83   25.97
#          2014.0                  0.02  12.61   99.97
#          2015.0                  0.01  14.63  118.96
#          2016.0                  0.01   7.59   69.29
# ...

# %%
df15=df5[df5['Platform'].isin(['Wii','PS3','X360'])]
df15
# Out:
#                                                     Name Platform  \
# 0                                             Wii Sports      Wii
# 2                                         Mario Kart Wii      Wii
# 3                                      Wii Sports Resort      Wii
# 7                                               Wii Play      Wii
# 8                              New Super Mario Bros. Wii      Wii
# 13                                               Wii Fit      Wii
# 14                                    Kinect Adventures!     X360
# 15                                          Wii Fit Plus      Wii
# 16                                    Grand Theft Auto V      PS3
# 23                                    Grand Theft Auto V     X360
# 29                        Call of Duty: Modern Warfare 3     X360
# 32                               Call of Duty: Black Ops     X360
# 34                            Call of Duty: Black Ops II      PS3
# ...

# %%
df15.Platform.unique()
# Out:
# array(['Wii', 'X360', 'PS3'], dtype=object)

# %%
df5.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
f=['Global_Sales','JP_Sales','NA_Sales','Other_Sales']

# %%
pd.plotting.scatter_matrix(df15[f]);

# %%
sns.pairplot(df15[['Global_Sales','JP_Sales','NA_Sales','Other_Sales','Platform']],hue='Platform');

# %%
df15.plot();
